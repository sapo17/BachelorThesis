# %%
import mitsuba as mi
mi.set_variant('llvm_ad_rgb')

# %%
scene = mi.load_file('scenes/cbox/cbox.xml')
image_ref = mi.render(scene, spp=64)
mi.util.convert_to_bitmap(image_ref)
# Out:
# Bitmap[
#   pixel_format = rgb,
#   component_format = uint8,
#   size = [256, 256],
#   srgb_gamma = 1,
#   struct = Struct<3>[
#     uint8 R; // @0, normalized, gamma, premultiplied alpha
#     uint8 G; // @1, normalized, gamma, premultiplied alpha
#     uint8 B; // @2, normalized, gamma, premultiplied alpha
#   ],
#   data = [ 192 KiB of image data ]
# ]

# %%
scene_params = mi.traverse(scene)
type(scene_params)
# Out:
# mitsuba.python.util.SceneParameters

# %%
scene_params
# Out:
# SceneParameters[
#   ------------------------------------------------------------------------------------------
#   Name                                   Flags    Type            Parent
#   ------------------------------------------------------------------------------------------
#   PerspectiveCamera.near_clip                     float           PerspectiveCamera
#   PerspectiveCamera.far_clip                      float           PerspectiveCamera
#   PerspectiveCamera.shutter_open                  float           PerspectiveCamera
#   PerspectiveCamera.shutter_open_time             float           PerspectiveCamera
#   PerspectiveCamera.film.size                     ScalarVector2u  HDRFilm
#   PerspectiveCamera.film.crop_size                ScalarVector2u  HDRFilm
#   PerspectiveCamera.film.crop_offset              ScalarPoint2u   HDRFilm
#   PerspectiveCamera.x_fov                         Float           PerspectiveCamera
#   PerspectiveCamera.to_world                      Transform4f     PerspectiveCamera
#   box.reflectance.value                  ∂        Color3f         SRGBReflectanceSpectrum
#   white.reflectance.value                ∂        Color3f         SRGBReflectanceSpectrum
#   red.reflectance.value                  ∂        Color3f         SRGBReflectanceSpectrum
#   green.reflectance.value                ∂        Color3f         SRGBReflectanceSpectrum
#   light.reflectance.value                ∂        Color3f         SRGBReflectanceSpectrum
#   OBJMesh.emitter.radiance.value         ∂        Color3f         SRGBReflectanceSpectrum
#   OBJMesh.vertex_count                            int             OBJMesh
#   OBJMesh.face_count                              int             OBJMesh
#   OBJMesh.faces                                   UInt            OBJMesh
#   OBJMesh.vertex_positions               ∂, D     Float           OBJMesh
#   OBJMesh.vertex_normals                 ∂, D     Float           OBJMesh
#   OBJMesh.vertex_texcoords               ∂        Float           OBJMesh
#   OBJMesh_1.vertex_count                          int             OBJMesh
#   OBJMesh_1.face_count                            int             OBJMesh
#   OBJMesh_1.faces                                 UInt            OBJMesh
#   OBJMesh_1.vertex_positions             ∂, D     Float           OBJMesh
#   OBJMesh_1.vertex_normals               ∂, D     Float           OBJMesh
#   OBJMesh_1.vertex_texcoords             ∂        Float           OBJMesh
#   OBJMesh_2.vertex_count                          int             OBJMesh
#   OBJMesh_2.face_count                            int             OBJMesh
#   OBJMesh_2.faces                                 UInt            OBJMesh
#   OBJMesh_2.vertex_positions             ∂, D     Float           OBJMesh
#   OBJMesh_2.vertex_normals               ∂, D     Float           OBJMesh
#   OBJMesh_2.vertex_texcoords             ∂        Float           OBJMesh
#   OBJMesh_3.vertex_count                          int             OBJMesh
#   OBJMesh_3.face_count                            int             OBJMesh
#   OBJMesh_3.faces                                 UInt            OBJMesh
#   OBJMesh_3.vertex_positions             ∂, D     Float           OBJMesh
#   OBJMesh_3.vertex_normals               ∂, D     Float           OBJMesh
#   OBJMesh_3.vertex_texcoords             ∂        Float           OBJMesh
#   OBJMesh_4.vertex_count                          int             OBJMesh
#   OBJMesh_4.face_count                            int             OBJMesh
#   OBJMesh_4.faces                                 UInt            OBJMesh
#   OBJMesh_4.vertex_positions             ∂, D     Float           OBJMesh
#   OBJMesh_4.vertex_normals               ∂, D     Float           OBJMesh
#   OBJMesh_4.vertex_texcoords             ∂        Float           OBJMesh
#   OBJMesh_5.vertex_count                          int             OBJMesh
#   OBJMesh_5.face_count                            int             OBJMesh
#   OBJMesh_5.faces                                 UInt            OBJMesh
#   OBJMesh_5.vertex_positions             ∂, D     Float           OBJMesh
#   OBJMesh_5.vertex_normals               ∂, D     Float           OBJMesh
#   OBJMesh_5.vertex_texcoords             ∂        Float           OBJMesh
#   OBJMesh_6.vertex_count                          int             OBJMesh
#   OBJMesh_6.face_count                            int             OBJMesh
#   OBJMesh_6.faces                                 UInt            OBJMesh
#   OBJMesh_6.vertex_positions             ∂, D     Float           OBJMesh
#   OBJMesh_6.vertex_normals               ∂, D     Float           OBJMesh
#   OBJMesh_6.vertex_texcoords             ∂        Float           OBJMesh
#   OBJMesh_7.vertex_count                          int             OBJMesh
#   OBJMesh_7.face_count                            int             OBJMesh
#   OBJMesh_7.faces                                 UInt            OBJMesh
#   OBJMesh_7.vertex_positions             ∂, D     Float           OBJMesh
#   OBJMesh_7.vertex_normals               ∂, D     Float           OBJMesh
#   OBJMesh_7.vertex_texcoords             ∂        Float           OBJMesh
# ]

# %%
param_key = 'red.reflectance.value'
param_ref = mi.Color3f(scene_params[param_key])
scene_params[param_key] = mi.Color3f(0.01, 0.0, 0.9)

# %%
scene_params.update();

# %%
image = mi.render(scene, spp=1024)
mi.util.convert_to_bitmap(image)
# Out:
# Bitmap[
#   pixel_format = rgb,
#   component_format = uint8,
#   size = [256, 256],
#   srgb_gamma = 1,
#   struct = Struct<3>[
#     uint8 R; // @0, normalized, gamma, premultiplied alpha
#     uint8 G; // @1, normalized, gamma, premultiplied alpha
#     uint8 B; // @2, normalized, gamma, premultiplied alpha
#   ],
#   data = [ 192 KiB of image data ]
# ]

# %% [markdown]
# ### Goal: Recover original scene, by optimizing BSDF reflectance value

# %%
opt = mi.ad.Adam(lr=0.05)

# %%
help(mi.ad.Adam)
# Out:
# Help on class Adam in module mitsuba.ad.optimizers:
#
# class Adam(Optimizer)
#  |  Adam(lr, beta_1=0.9, beta_2=0.999, epsilon=1e-08, mask_updates=False, uniform=False, params: dict = None)
#  |
#  |  Implements the Adam optimizer presented in the paper *Adam: A Method for
#  |  Stochastic Optimization* by Kingman and Ba, ICLR 2015.
#  |
#  |  When optimizing many variables (e.g. a high resolution texture) with
#  |  momentum enabled, it may be beneficial to restrict state and variable
#  |  updates to the entries that received nonzero gradients in the current
#  |  iteration (``mask_updates=True``).
#  |  In the context of differentiable Monte Carlo simulations, many of those
#  |  variables may not be observed at each iteration, e.g. when a surface is
#  |  not visible from the current camera. Gradients for unobserved variables
#  |  will remain at zero by default.
#  |  If we do not take special care, at each new iteration:
#  |
#  |  1. Momentum accumulated at previous iterations (potentially very noisy)
#  |     will keep being applied to the variable.
#  |  2. The optimizer's state will be updated to incorporate ``gradient = 0``,
#  |     even though it is not an actual gradient value but rather lack of one.
#  |
#  |  Enabling ``mask_updates`` avoids these two issues. This is similar to
#  |  `PyTorch's SparseAdam optimizer <https://pytorch.org/docs/1.9.0/generated/torch.optim.SparseAdam.html>`_.
#  |
#  |  Method resolution order:
#  |      Adam
#  |      Optimizer
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, lr, beta_1=0.9, beta_2=0.999, epsilon=1e-08, mask_updates=False, uniform=False, params: dict = None)
#  |      Parameter ``lr``:
#  |          learning rate
#  |
#  |      Parameter ``beta_1``:
#  |          controls the exponential averaging of first order gradient moments
#  |
#  |      Parameter ``beta_2``:
#  |          controls the exponential averaging of second order gradient moments
#  |
#  |      Parameter ``mask_updates``:
#  |          if enabled, parameters and state variables will only be updated in a
#  |          given iteration if it received nonzero gradients in that iteration
#  |
#  |      Parameter ``uniform``:
#  |          if enabled, the optimizer will use the 'UniformAdam' variant of Adam
#  |          [Nicolet et al. 2021], where the update rule uses the *maximum* of
#  |          the second moment estimates at the current step instead of the
#  |          per-element second moments.
#  |
#  |      Parameter ``params`` (:py:class:`dict`):
#  |          Optional dictionary-like object containing parameters to optimize.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  reset(self, key)
#  |      Zero-initializes the internal state associated with a parameter
#  |
#  |  step(self)
#  |      Take a gradient step
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from Optimizer:
#  |
#  |  __contains__(self, key: str)
#  |
#  |  __delitem__(self, key: str) -> None
#  |
#  |  __getitem__(self, key: str)
#  |
#  |  __len__(self) -> int
#  |
#  |  __setitem__(self, key: str, value)
#  |      Overwrite the value of a parameter.
#  |
#  |      This method can also be used to load a scene parameters to optimize.
#  |
#  |      Note that the state of the optimizer (e.g. momentum) associated with the
#  |      parameter is preserved, unless the parameter's dimensions changed. When
#  |      assigning a substantially different parameter value (e.g. as part of a
#  |      different optimization run), the previous momentum value is meaningless
#  |      and calling `reset()` is advisable.
#  |
#  |  items(self)
#  |
#  |  keys(self)
#  |
#  |  set_learning_rate(self, lr) -> None
#  |      Set the learning rate.
#  |
#  |      Parameter ``lr`` (``float``, ``dict``):
#  |          The new learning rate. A ``dict`` can be provided instead to
#  |          specify the learning rate for specific parameters.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from Optimizer:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
opt[param_key] = scene_params[param_key]

# %%
scene_params.update(opt)
# Out:
# [(SRGBReflectanceSpectrum[
#     value = [[0.01, 0, 0.9]]
#   ],
#   {'value'}),
#  (SmoothDiffuse[
#     reflectance = SRGBReflectanceSpectrum[
#       value = [[0.01, 0, 0.9]]
#     ]
#   ],
#   {'reflectance'}),
#  (Scene[
#     children = [
#       PathIntegrator[
#         max_depth = 6,
#         rr_depth = 5
#       ],
#       PerspectiveCamera[
#         x_fov = [39.3077],
#         near_clip = 10,
#         far_clip = 2800,
#         film = HDRFilm[
#           size = [256, 256],
#           crop_size = [256, 256],
#           crop_offset = [0, 0],
#           sample_border = 0,
#           filter = GaussianFilter[stddev=0.50, radius=2.00],
#           file_format = OpenEXR,
#           pixel_format = rgb,
#           component_format = float16,
#         ],
#         sampler = IndependentSampler[
#           base_seed = 0
#           sample_count = 1024
#           samples_per_wavefront = 1024
#           wavefront_size = 67108864
#         ],
#         resolution = [256, 256],
#         shutter_open = 0,
#         shutter_open_time = 0,
#         to_world = [[1, 0, 0, 278],
#                     [0, 1, 0, 273],
#                     [0, 0, 1, -800],
#                     [0, 0, 0, 1]]
#       ],
#       SmoothDiffuse[
#         reflectance = SRGBReflectanceSpectrum[
#           value = [[0.735013, 0.735625, 0.736264]]
#         ]
#       ],
#       SmoothDiffuse[
#         reflectance = SRGBReflectanceSpectrum[
#           value = [[0.735013, 0.735625, 0.736264]]
#         ]
#       ],
#       SmoothDiffuse[
#         reflectance = SRGBReflectanceSpectrum[
#           value = [[0.01, 0, 0.9]]
#         ]
#       ],
#       SmoothDiffuse[
#         reflectance = SRGBReflectanceSpectrum[
#           value = [[0.0682825, 0.39776, 0.0862909]]
#         ]
#       ],
#       SmoothDiffuse[
#         reflectance = SRGBReflectanceSpectrum[
#           value = [[0.776367, 0.77981, 0.776029]]
#         ]
#       ],
#       OBJMesh[
#         name = "cbox_luminaire.obj",
#         bbox = BoundingBox3f[
#           min = [213, 548.3, 227],
#           max = [343, 548.3, 332]
#         ],
#         vertex_count = 4,
#         vertices = [96 B of vertex data],
#         face_count = 2,
#         faces = [24 B of face data],
#         surface_area = [13650],
#         face_normals = 0
#       ],
#       OBJMesh[
#         name = "cbox_floor.obj",
#         bbox = BoundingBox3f[
#           min = [0, 0, 0],
#           max = [552.8, 0, 559.2]
#         ],
#         vertex_count = 4,
#         vertices = [96 B of vertex data],
#         face_count = 2,
#         faces = [24 B of face data],
#         face_normals = 0
#       ],
#       OBJMesh[
#         name = "cbox_ceiling.obj",
#         bbox = BoundingBox3f[
#           min = [0, 548.8, 0],
#           max = [556, 548.8, 559.2]
#         ],
#         vertex_count = 8,
#         vertices = [192 B of vertex data],
#         face_count = 4,
#         faces = [48 B of face data],
#         face_normals = 0
#       ],
#       OBJMesh[
#         name = "cbox_back.obj",
#         bbox = BoundingBox3f[
#           min = [0, 0, 559.2],
#           max = [556, 548.8, 559.2]
#         ],
#         vertex_count = 4,
#         vertices = [96 B of vertex data],
#         face_count = 2,
#         faces = [24 B of face data],
#         face_normals = 0
#       ],
#       OBJMesh[
#         name = "cbox_greenwall.obj",
#         bbox = BoundingBox3f[
#           min = [0, 0, 0],
#           max = [0, 548.8, 559.2]
#         ],
#         vertex_count = 4,
#         vertices = [96 B of vertex data],
#         face_count = 2,
#         faces = [24 B of face data],
#         face_normals = 0
#       ],
#       OBJMesh[
#         name = "cbox_redwall.obj",
#         bbox = BoundingBox3f[
#           min = [549.6, 0, 0],
#           max = [556, 548.8, 559.2]
#         ],
#         vertex_count = 4,
#         vertices = [96 B of vertex data],
#         face_count = 2,
#         faces = [24 B of face data],
#         face_normals = 0
#       ],
#       OBJMesh[
#         name = "cbox_smallbox.obj",
#         bbox = BoundingBox3f[
#           min = [82, 0, 65],
#           max = [290, 165, 272]
#         ],
#         vertex_count = 24,
#         vertices = [576 B of vertex data],
#         face_count = 12,
#         faces = [144 B of face data],
#         face_normals = 0
#       ],
#       OBJMesh[
#         name = "cbox_largebox.obj",
#         bbox = BoundingBox3f[
#           min = [265, 0, 247],
#           max = [472, 330, 456]
#         ],
#         vertex_count = 24,
#         vertices = [576 B of vertex data],
#         face_count = 12,
#         faces = [144 B of face data],
#         face_normals = 0
#       ]
#     ]
#   ],
#   {'red'})]

# %%
import drjit as dr

def mean_squared_error(image):
    return dr.mean(dr.sqr(image - image_ref))

# %%
# gradient decent loop
images = []
for it in range(50):
    # render the scene and compute the loss
    image = mi.render(scene, scene_params, spp=4)
    loss = mean_squared_error(image)

    # trigger jti to backpropogate the loss
    # backpropogate the loss up to the parameter that we enabled the optimizer
    dr.backward(loss)
    opt.step()

    # might need to post process since parameter might left the domain in which
    # is undefined
    opt[param_key] = dr.clamp(opt[param_key], 0.0, 1.0)

    scene_params.update(opt)

    err_ref = dr.sum(dr.sqr(param_ref - scene_params[param_key]))
    print(f"Iteration {it:02d}: parameter error = {err_ref[0]:6f}", end='\r')
    images.append(image)
print('\nOptimization complete.')
# Out:
# Iteration 49: parameter error = 0.001311
# Optimization complete.

# %%
images
# Out:
# [TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3)),
#  TensorXf(shape=(256, 256, 3))]

# %%
optimized_image = images.pop()

# %% [markdown]
# ### Optimized Image (Blue wall -> Red Wall)

# %%
mi.util.convert_to_bitmap(optimized_image)
# Out:
# Bitmap[
#   pixel_format = rgb,
#   component_format = uint8,
#   size = [256, 256],
#   srgb_gamma = 1,
#   struct = Struct<3>[
#     uint8 R; // @0, normalized, gamma, premultiplied alpha
#     uint8 G; // @1, normalized, gamma, premultiplied alpha
#     uint8 B; // @2, normalized, gamma, premultiplied alpha
#   ],
#   data = [ 192 KiB of image data ]
# ]

# %% [markdown]
# ### Image before Optimization

# %%
# initial image
mi.util.convert_to_bitmap(images[0])
# Out:
# Bitmap[
#   pixel_format = rgb,
#   component_format = uint8,
#   size = [256, 256],
#   srgb_gamma = 1,
#   struct = Struct<3>[
#     uint8 R; // @0, normalized, gamma, premultiplied alpha
#     uint8 G; // @1, normalized, gamma, premultiplied alpha
#     uint8 B; // @2, normalized, gamma, premultiplied alpha
#   ],
#   data = [ 192 KiB of image data ]
# ]

# %% [markdown]
# ### Reference (Original) image

# %%
mi.util.convert_to_bitmap(image_ref)
# Out:
# Bitmap[
#   pixel_format = rgb,
#   component_format = uint8,
#   size = [256, 256],
#   srgb_gamma = 1,
#   struct = Struct<3>[
#     uint8 R; // @0, normalized, gamma, premultiplied alpha
#     uint8 G; // @1, normalized, gamma, premultiplied alpha
#     uint8 B; // @2, normalized, gamma, premultiplied alpha
#   ],
#   data = [ 192 KiB of image data ]
# ]
